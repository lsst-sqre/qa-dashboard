# %%
import json
with open('Cfht_output_r.json') as f:
    data=json.load(f)

# %%
data.keys()
# Out:
# [u'measurements', u'blobs']

# %%
data['blobs'][0].keys()
# Out:
# [u'identifier', u'data', u'name']

# %%
data['blobs'][0]['data'].keys()
# Out:
# [u'magerr', u'dist', u'filterName', u'magrms', u'snr', u'mag']

# %%
data['measurements'][0]
# Out:
# {u'blobs': {u'astromModel': u'7bac9df38e394f93a493defd4509972a',
#   u'matchedDataset': u'201ea23d75a7421a8dc9e92db412e4ca',
#   u'photomModel': u'8e04a120e4b14ede8b8863551400ba68'},
#  u'extras': {u'iqr': {u'description': u'Photometric repeatability IQR of stellar pairs for each random sample',
#    u'label': u'IQR',
#    u'unit': u'mmag',
#    u'value': [16.94287029694786,
#     16.983660154049797,
#     16.65385220960986,
#     16.564582448606153,
#     16.318082893985746,
#     16.76750102463645,
#     16.838050002510855,
#     16.64007365363466,
#     16.6734989561527,
#     16.195819580133005,
#     16.01686793741438,
#     16.93347394299048,
#     16.623678528578832,
#     16.330581736431554,
#     15.999689022407326,
#     17.156719096613354,
#     16.358925077705464,
#     16.158343722993997,
#     16.44641142695126,
#     16.660525612785534,
#     15.888204954085477,
#     16.393427963650076,
#     16.555840110929843,
#     16.738327141947646,
#     16.13375880887994,
# ...

# %%
m=data['measurements'][0]

# %%
m['blobs']
# Out:
# {u'astromModel': u'7bac9df38e394f93a493defd4509972a',
#  u'matchedDataset': u'201ea23d75a7421a8dc9e92db412e4ca',
#  u'photomModel': u'8e04a120e4b14ede8b8863551400ba68'}

# %%
data['blobs'][0].keys()
# Out:
# [u'identifier', u'data', u'name']

# %%
m['value']
# Out:
# 16.612117529937006

# %%
m['unit']
# Out:
# u'mmag'

# %%
m['metric']
# Out:
# {u'description': u'The maximum rms of the unresolved source magnitude distribution around the mean value (repeatability).\n',
#  u'name': u'PA1',
#  u'operator_str': u'<=',
#  u'parameters': {},
#  u'reference': {u'doc': u'LPM-17',
#   u'page': 21,
#   u'url': u'http://ls.st/lpm-17'},
#  u'specifications': [{u'dependencies': {},
#    u'filter_names': [u'g', u'r', u'i'],
#    u'name': u'design',
#    u'unit': u'mmag',
#    u'value': 5.0},
#   {u'dependencies': {},
#    u'filter_names': [u'u', u'z', u'y'],
#    u'name': u'design',
#    u'unit': u'mmag',
#    u'value': 7.5},
#   {u'dependencies': {},
#    u'filter_names': [u'g', u'r', u'i'],
#    u'name': u'minimum',
#    u'unit': u'mmag',
#    u'value': 8.0},
#   {u'dependencies': {},
#    u'filter_names': [u'u', u'z', u'y'],
#    u'name': u'minimum',
#    u'unit': u'mmag',
#    u'value': 12.0},
#   {u'dependencies': {},
#    u'filter_names': [u'g', u'r', u'i'],
#    u'name': u'stretch',
#    u'unit': u'mmag',
#    u'value': 3.0},
# ...

# %%
m['parameters']
# Out:
# {u'numRandomShuffles': {u'description': u'Number of random shuffles',
#   u'label': u'shuffles',
#   u'unit': u'',
#   u'value': 50}}

# %%
m['extras']
# Out:
# {u'iqr': {u'description': u'Photometric repeatability IQR of stellar pairs for each random sample',
#   u'label': u'IQR',
#   u'unit': u'mmag',
#   u'value': [16.94287029694786,
#    16.983660154049797,
#    16.65385220960986,
#    16.564582448606153,
#    16.318082893985746,
#    16.76750102463645,
#    16.838050002510855,
#    16.64007365363466,
#    16.6734989561527,
#    16.195819580133005,
#    16.01686793741438,
#    16.93347394299048,
#    16.623678528578832,
#    16.330581736431554,
#    15.999689022407326,
#    17.156719096613354,
#    16.358925077705464,
#    16.158343722993997,
#    16.44641142695126,
#    16.660525612785534,
#    15.888204954085477,
#    16.393427963650076,
#    16.555840110929843,
#    16.738327141947646,
#    16.13375880887994,
#    16.383857365844545,
#    16.205816119560822,
#    16.365903773667256,
#    16.19649161756809,
#    16.82480078235854,
#    16.598622146119844,
#    16.746101286091886,
#    17.040353642236433,
#    16.742922961757188,
# ...
